# %% [markdown]
# # Hidden Markov Model (HMM) Implementation
#
# This notebook implements and trains the HMM for letter probability estimation.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict, Counter
import pickle
import sys
sys.path.append('../src')

# %matplotlib inline

# %% [markdown]
# ## Load corpus and implement HMM here
