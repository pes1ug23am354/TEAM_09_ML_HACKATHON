# %% [markdown]
# # Evaluation
#
# Evaluate the trained agent on test set (2000 words).

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.append('../src')

# %matplotlib inline

# %% [markdown]
# ## Evaluate on test.txt here
